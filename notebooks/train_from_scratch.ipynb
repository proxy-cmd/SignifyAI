# %% [markdown]
# # SignifyAI Training Notebook
# Use this notebook to train from scratch on your dataset.

# %%
import pandas as pd
df = pd.read_csv('data/processed/dataset.csv')
print('Shape:', df.shape)
print(df['label'].value_counts())

# %%
# !python -u src/main.py train-all --dataset data/processed/dataset.csv

# %%
import json
from pathlib import Path
summary = Path('models/train_all_summary.json')
print(summary.read_text(encoding='utf-8'))

# %%
# !python -u src/main.py validate-all --no-pytest
